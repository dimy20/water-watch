# %%
import pandas as pd

# %%
stations_df = pd.read_csv("../GFQA_v3/GEMStat_station_metadata.csv", encoding='ISO-8859-1')

# %% [markdown]
# ## Estaciones en uruguay
# Una estación es un punto físico fijo de monitoreo — por ejemplo, un sensor o punto de muestreo ubicado en un río, lago o arroyo específico. Tiene coordenadas fijas y se le toman mediciones periódicamente a lo largo del tiempo.

# %%
df = stations_df[stations_df["Country Name"] == "Uruguay"]
total_stations = len(df)
station_prefix = "UYU"
print(f"Uruguay tiene un total de {total_stations} Estaciones de monitoreo")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = stations_df[stations_df["Country Name"] == "Uruguay"]
#       2 total_stations = len(df)
#       3 station_prefix = "UYU"
#       4 print(f"Uruguay tiene un total de {total_stations} Estaciones de monitoreo")
#
# NameError: name 'stations_df' is not defined

# %%
df.head()
# Out:
#       GEMS Station Number Local Station Number Country Name     Water Type  \
# 22621            URY00006                 08AB      Uruguay  River station
# 22622            URY00007                 03LP      Uruguay  River station
# 22623            URY00008                 06SF      Uruguay  River station
# 22624            URY00009                 04SF      Uruguay  River station
# 22625            URY00010                 05SF      Uruguay  River station
#
#               Station Identifier          Station Narrative Water Body Name  \
# 22621              Aguas Blancas              Aguas Blancas             NaN
# 22622            Arroyo La Plata            Arroyo La Plata             NaN
# 22623  Arroyo San Francisco P...  Arroyo San Francisco P...             NaN
# 22624  Arroyo San Francisco P...  Arroyo San Francisco P...             NaN
# 22625  Arroyo San Francisco P...  Arroyo San Francisco P...             NaN
#
# ...

# %%
df.iloc[0]
# Out:
# GEMS Station Number                                    URY00006
# Local Station Number                                       08AB
# Country Name                                            Uruguay
# Water Type                                        River station
# Station Identifier                                Aguas Blancas
# Station Narrative                                 Aguas Blancas
# Water Body Name                                             NaN
# Main Basin                                             LA PLATA
# Upstream Basin Area                                         NaN
# Elevation                                                  87.0
# Monitoring Type                                           TREND
# Date Station Opened                                         NaN
# Responsible Collection Agency    Ministerio de Ambiente Uruguay
# Latitude                                               -34.5071
# Longitude                                              -55.3727
# ...
